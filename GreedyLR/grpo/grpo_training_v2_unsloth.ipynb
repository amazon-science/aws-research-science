# %%
# !export CUDA_HOME=/usr/local/cuda-12.5/ && pip install trl accelerate vllm transformer_engine[pytorch]
# Out:
# Collecting trl
#   Using cached trl-0.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.11/site-packages (0.21.0)
# Collecting vllm
#   Using cached vllm-0.7.2-cp38-abi3-manylinux1_x86_64.whl.metadata (12 kB)
# Collecting transformer_engine[pytorch]
#   Using cached transformer_engine-1.13.0-py3-none-any.whl.metadata (16 kB)
# Collecting accelerate
#   Using cached accelerate-1.3.0-py3-none-any.whl.metadata (19 kB)
# Collecting datasets>=2.21.0 (from trl)
#   Using cached datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: rich in /opt/conda/lib/python3.11/site-packages (from trl) (13.9.4)
# Collecting transformers>=4.46.0 (from trl)
#   Using cached transformers-4.48.2-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /opt/conda/lib/python3.11/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.11/site-packages (from accelerate) (5.9.8)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from accelerate) (2.3.1.post300)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /opt/conda/lib/python3.11/site-packages (from accelerate) (0.28.1)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/conda/lib/python3.11/site-packages (from accelerate) (0.4.5)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.11/site-packages (from vllm) (0.1.99)
# Requirement already satisfied: requests>=2.26.0 in /opt/conda/lib/python3.11/site-packages (from vllm) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from vllm) (4.67.0)
# Collecting blake3 (from vllm)
#   Using cached blake3-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting py-cpuinfo (from vllm)
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting tokenizers>=0.19.1 (from vllm)
#   Using cached tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.11/site-packages (from vllm) (4.25.3)
# Requirement already satisfied: fastapi!=0.113.*,!=0.114.0,>=0.107.0 in /opt/conda/lib/python3.11/site-packages (from vllm) (0.110.3)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.11/site-packages (from vllm) (3.9.5)
# Collecting openai>=1.52.0 (from vllm)
#   Using cached openai-1.61.1-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: uvicorn[standard] in /opt/conda/lib/python3.11/site-packages (from vllm) (0.30.6)
# Collecting pydantic>=2.9 (from vllm)
#   Using cached pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: prometheus_client>=0.18.0 in /opt/conda/lib/python3.11/site-packages (from vllm) (0.21.0)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.11/site-packages (from vllm) (10.4.0)
# Collecting prometheus-fastapi-instrumentator>=7.0.0 (from vllm)
#   Using cached prometheus_fastapi_instrumentator-7.0.2-py3-none-any.whl.metadata (13 kB)
# Collecting tiktoken>=0.6.0 (from vllm)
#   Using cached tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting lm-format-enforcer<0.11,>=0.10.9 (from vllm)
#   Using cached lm_format_enforcer-0.10.9-py3-none-any.whl.metadata (17 kB)
# Collecting outlines==0.1.11 (from vllm)
#   Using cached outlines-0.1.11-py3-none-any.whl.metadata (17 kB)
# Collecting lark==1.2.2 (from vllm)
#   Using cached lark-1.2.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting xgrammar>=0.1.6 (from vllm)
#   Using cached xgrammar-0.1.11-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: typing_extensions>=4.10 in /opt/conda/lib/python3.11/site-packages (from vllm) (4.12.2)
# Requirement already satisfied: filelock>=3.16.1 in /opt/conda/lib/python3.11/site-packages (from vllm) (3.16.1)
# Collecting partial-json-parser (from vllm)
#   Using cached partial_json_parser-0.2.1.1.post5-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pyzmq in /opt/conda/lib/python3.11/site-packages (from vllm) (26.2.0)
# Collecting msgspec (from vllm)
#   Using cached msgspec-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting gguf==0.10.0 (from vllm)
#   Using cached gguf-0.10.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: importlib_metadata in /opt/conda/lib/python3.11/site-packages (from vllm) (6.10.0)
# Collecting mistral_common>=1.5.0 (from mistral_common[opencv]>=1.5.0->vllm)
#   Using cached mistral_common-1.5.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting einops (from vllm)
#   Using cached einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting compressed-tensors==0.9.1 (from vllm)
#   Using cached compressed_tensors-0.9.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting depyf==0.18.0 (from vllm)
#   Using cached depyf-0.18.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.11/site-packages (from vllm) (2.2.1)
# Requirement already satisfied: ray>=2.9 in /opt/conda/lib/python3.11/site-packages (from ray[default]>=2.9->vllm) (2.37.0)
# Collecting nvidia-ml-py>=12.560.30 (from vllm)
#   Using cached nvidia_ml_py-12.570.86-py3-none-any.whl.metadata (8.7 kB)
# Collecting torch>=2.0.0 (from accelerate)
#   Using cached torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting torchaudio==2.5.1 (from vllm)
#   Using cached torchaudio-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.4 kB)
# Collecting torchvision==0.20.1 (from vllm)
#   Using cached torchvision-0.20.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.1 kB)
# Collecting xformers==0.0.28.post3 (from vllm)
#   Using cached xformers-0.0.28.post3-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# Collecting astor (from depyf==0.18.0->vllm)
#   Using cached astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: dill in /opt/conda/lib/python3.11/site-packages (from depyf==0.18.0->vllm) (0.3.9)
# Collecting interegular (from outlines==0.1.11->vllm)
#   Using cached interegular-0.3.3-py37-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (3.1.4)
# Requirement already satisfied: nest_asyncio in /opt/conda/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (1.6.0)
# Requirement already satisfied: diskcache in /opt/conda/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (5.6.3)
# Requirement already satisfied: referencing in /opt/conda/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (0.35.1)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (4.23.0)
# Collecting pycountry (from outlines==0.1.11->vllm)
#   Using cached pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Collecting airportsdata (from outlines==0.1.11->vllm)
#   Using cached airportsdata-20241001-py3-none-any.whl.metadata (8.9 kB)
# Collecting outlines_core==0.1.26 (from outlines==0.1.11->vllm)
#   Using cached outlines_core-0.1.26-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->accelerate)
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->accelerate)
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->accelerate)
#   Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->accelerate)
#   Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->accelerate)
#   Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->accelerate)
#   Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=2.0.0->accelerate)
#   Using cached nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Using cached nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch>=2.0.0->accelerate)
#   Using cached triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting sympy==1.13.1 (from torch>=2.0.0->accelerate)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Collecting transformer_engine_cu12==1.13.0 (from transformer_engine[pytorch])
#   Using cached transformer_engine_cu12-1.13.0-py3-none-manylinux_2_28_x86_64.whl.metadata (16 kB)
# Collecting transformer_engine_torch==1.13.0 (from transformer_engine[pytorch])
#   Using cached transformer_engine_torch-1.13.0.tar.gz (121 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.11/site-packages (from datasets>=2.21.0->trl) (15.0.2)
# Collecting dill (from depyf==0.18.0->vllm)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from datasets>=2.21.0->trl) (2.2.3)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.11/site-packages (from datasets>=2.21.0->trl) (3.5.0)
# Collecting multiprocess<0.70.17 (from datasets>=2.21.0->trl)
#   Using cached multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /opt/conda/lib/python3.11/site-packages (from fastapi!=0.113.*,!=0.114.0,>=0.107.0->vllm) (0.37.2)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib_metadata->vllm) (3.21.0)
# Collecting sentencepiece (from vllm)
#   Using cached sentencepiece-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting tiktoken>=0.6.0 (from vllm)
#   Using cached tiktoken-0.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting opencv-python-headless<5.0.0,>=4.0.0 (from mistral_common[opencv]>=1.5.0->vllm)
#   Using cached opencv_python_headless-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/lib/python3.11/site-packages (from openai>=1.52.0->vllm) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.11/site-packages (from openai>=1.52.0->vllm) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.11/site-packages (from openai>=1.52.0->vllm) (0.27.2)
# Collecting jiter<1,>=0.4.0 (from openai>=1.52.0->vllm)
#   Using cached jiter-0.8.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.11/site-packages (from openai>=1.52.0->vllm) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.9->vllm) (0.7.0)
# Collecting pydantic-core==2.27.2 (from pydantic>=2.9->vllm)
#   Using cached pydantic_core-2.27.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.26.0->vllm) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.26.0->vllm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.26.0->vllm) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.26.0->vllm) (2024.8.30)
# Requirement already satisfied: regex>=2022.1.18 in /opt/conda/lib/python3.11/site-packages (from tiktoken>=0.6.0->vllm) (2024.11.6)
# Collecting pybind11 (from xgrammar>=0.1.6->vllm)
#   Using cached pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# Collecting pytest (from xgrammar>=0.1.6->vllm)
#   Using cached pytest-8.3.4-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp->vllm) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->vllm) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp->vllm) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp->vllm) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->vllm) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from rich->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich->trl) (2.18.0)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.11/site-packages (from uvicorn[standard]->vllm) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.11/site-packages (from uvicorn[standard]->vllm) (0.14.0)
# Collecting httptools>=0.5.0 (from uvicorn[standard]->vllm)
#   Using cached httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]->vllm)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]->vllm)
#   Using cached uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]->vllm)
#   Using cached watchfiles-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]->vllm)
#   Using cached websockets-14.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai>=1.52.0->vllm) (1.0.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema->outlines==0.1.11->vllm) (2024.10.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema->outlines==0.1.11->vllm) (0.21.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->trl) (0.1.2)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.11/site-packages (from yarl<2.0,>=1.0->aiohttp->vllm) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->outlines==0.1.11->vllm) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets>=2.21.0->trl) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets>=2.21.0->trl) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets>=2.21.0->trl) (2024.2)
# Collecting iniconfig (from pytest->xgrammar>=0.1.6->vllm)
#   Using cached iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: pluggy<2,>=1.5 in /opt/conda/lib/python3.11/site-packages (from pytest->xgrammar>=0.1.6->vllm) (1.5.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.21.0->trl) (1.16.0)
# Using cached trl-0.14.0-py3-none-any.whl (313 kB)
# Using cached accelerate-1.3.0-py3-none-any.whl (336 kB)
# Using cached vllm-0.7.2-cp38-abi3-manylinux1_x86_64.whl (264.3 MB)
# Using cached compressed_tensors-0.9.1-py3-none-any.whl (96 kB)
# Using cached depyf-0.18.0-py3-none-any.whl (38 kB)
# Using cached gguf-0.10.0-py3-none-any.whl (71 kB)
# Using cached lark-1.2.2-py3-none-any.whl (111 kB)
# Using cached outlines-0.1.11-py3-none-any.whl (87 kB)
# Using cached torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl (906.5 MB)
# Using cached torchaudio-2.5.1-cp311-cp311-manylinux1_x86_64.whl (3.4 MB)
# Using cached torchvision-0.20.1-cp311-cp311-manylinux1_x86_64.whl (7.2 MB)
# Using cached xformers-0.0.28.post3-cp311-cp311-manylinux_2_28_x86_64.whl (16.7 MB)
# Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
# Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
# Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
# Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
# Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
# Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
# Using cached nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
# Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Using cached nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Using cached outlines_core-0.1.26-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (343 kB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
# Using cached transformer_engine_cu12-1.13.0-py3-none-manylinux_2_28_x86_64.whl (125.2 MB)
# Using cached datasets-3.2.0-py3-none-any.whl (480 kB)
# Using cached lm_format_enforcer-0.10.9-py3-none-any.whl (43 kB)
# Using cached mistral_common-1.5.2-py3-none-any.whl (6.5 MB)
# Using cached sentencepiece-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Using cached nvidia_ml_py-12.570.86-py3-none-any.whl (44 kB)
# Using cached openai-1.61.1-py3-none-any.whl (463 kB)
# Using cached prometheus_fastapi_instrumentator-7.0.2-py3-none-any.whl (18 kB)
# Using cached pydantic-2.10.6-py3-none-any.whl (431 kB)
# Using cached pydantic_core-2.27.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# Using cached tiktoken-0.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Using cached tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# Using cached transformers-4.48.2-py3-none-any.whl (9.7 MB)
# Using cached xgrammar-0.1.11-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (396 kB)
# Using cached blake3-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (376 kB)
# Using cached einops-0.8.0-py3-none-any.whl (43 kB)
# Using cached msgspec-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (210 kB)
# Using cached partial_json_parser-0.2.1.1.post5-py3-none-any.whl (10 kB)
# Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Using cached transformer_engine-1.13.0-py3-none-any.whl (459 kB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Using cached httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
# Using cached interegular-0.3.3-py37-none-any.whl (23 kB)
# Using cached jiter-0.8.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (345 kB)
# Using cached multiprocess-0.70.16-py311-none-any.whl (143 kB)
# Using cached opencv_python_headless-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (50.0 MB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Using cached uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
# Using cached watchfiles-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (452 kB)
# Using cached websockets-14.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (169 kB)
# Using cached airportsdata-20241001-py3-none-any.whl (912 kB)
# Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Using cached pybind11-2.13.6-py3-none-any.whl (243 kB)
# Using cached pycountry-24.6.1-py3-none-any.whl (6.3 MB)
# Using cached pytest-8.3.4-py3-none-any.whl (343 kB)
# Using cached iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Building wheels for collected packages: transformer_engine_torch
#   Building wheel for transformer_engine_torch (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [9 lines of output]
#       Could not determine CUDA Toolkit version
#       /opt/conda/lib/python3.11/site-packages/setuptools/_distutils/dist.py:261: UserWarning: Unknown distribution option: 'tests_require'
#         warnings.warn(msg)
#       running bdist_wheel
#       /opt/conda/lib/python3.11/site-packages/torch/utils/cpp_extension.py:499: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#         warnings.warn(msg.format('we could not find ninja.'))
#       running build
#       running build_ext
#       error: [Errno 2] No such file or directory: '/usr/local/cuda-12.5/bin/nvcc'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for transformer_engine_torch
#   Running setup.py clean for transformer_engine_torch
# Failed to build transformer_engine_torch
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (transformer_engine_torch)

# %%
# !pip show trl
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Name: trl
# Version: 0.15.0.dev0
# Summary: Train transformer language models with reinforcement learning.
# Home-page: https://github.com/huggingface/trl
# Author: Leandro von Werra
# Author-email: leandro.vonwerra@gmail.com
# License: Apache 2.0
# Location: /opt/conda/lib/python3.11/site-packages
# Requires: accelerate, datasets, rich, transformers
# Required-by: unsloth, unsloth_zoo

# %%
# !pip install git+https://github.com/huggingface/trl.git@e95f9fb74a3c3647b86f251b7e230ec51c64b72b
# !pip install trl==0.14.0
# !pip install unsloth vllm
# !pip install --upgrade pillow diffusers
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting trl==0.14.0
#   Using cached trl-0.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: accelerate>=0.34.0 in /opt/conda/lib/python3.11/site-packages (from trl==0.14.0) (1.3.0)
# Requirement already satisfied: datasets>=2.21.0 in /opt/conda/lib/python3.11/site-packages (from trl==0.14.0) (3.2.0)
# Requirement already satisfied: rich in /opt/conda/lib/python3.11/site-packages (from trl==0.14.0) (13.9.4)
# Requirement already satisfied: transformers>=4.46.0 in /opt/conda/lib/python3.11/site-packages (from trl==0.14.0) (4.48.2)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /opt/conda/lib/python3.11/site-packages (from accelerate>=0.34.0->trl==0.14.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from accelerate>=0.34.0->trl==0.14.0) (24.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.11/site-packages (from accelerate>=0.34.0->trl==0.14.0) (5.9.8)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from accelerate>=0.34.0->trl==0.14.0) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from accelerate>=0.34.0->trl==0.14.0) (2.5.1)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /opt/conda/lib/python3.11/site-packages (from accelerate>=0.34.0->trl==0.14.0) (0.28.1)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/conda/lib/python3.11/site-packages (from accelerate>=0.34.0->trl==0.14.0) (0.4.5)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from datasets>=2.21.0->trl==0.14.0) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.11/site-packages (from datasets>=2.21.0->trl==0.14.0) (15.0.2)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.21.0->trl==0.14.0)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from datasets>=2.21.0->trl==0.14.0) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.11/site-packages (from datasets>=2.21.0->trl==0.14.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/conda/lib/python3.11/site-packages (from datasets>=2.21.0->trl==0.14.0) (4.67.0)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.11/site-packages (from datasets>=2.21.0->trl==0.14.0) (3.5.0)
# Collecting multiprocess<0.70.17 (from datasets>=2.21.0->trl==0.14.0)
#   Using cached multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /opt/conda/lib/python3.11/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=2.21.0->trl==0.14.0) (2023.6.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.11/site-packages (from datasets>=2.21.0->trl==0.14.0) (3.9.5)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.11/site-packages (from transformers>=4.46.0->trl==0.14.0) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/conda/lib/python3.11/site-packages (from transformers>=4.46.0->trl==0.14.0) (0.21.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from rich->trl==0.14.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich->trl==0.14.0) (2.18.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets>=2.21.0->trl==0.14.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets>=2.21.0->trl==0.14.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets>=2.21.0->trl==0.14.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets>=2.21.0->trl==0.14.0) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets>=2.21.0->trl==0.14.0) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate>=0.34.0->trl==0.14.0) (4.12.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->trl==0.14.0) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets>=2.21.0->trl==0.14.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets>=2.21.0->trl==0.14.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets>=2.21.0->trl==0.14.0) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets>=2.21.0->trl==0.14.0) (2024.8.30)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.14.0) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.14.0) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.14.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.14.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.14.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.14.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.14.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.14.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.14.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.14.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.14.0) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.14.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.14.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.14.0) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.14.0) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/conda/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.34.0->trl==0.14.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy==1.13.1->torch>=2.0.0->accelerate>=0.34.0->trl==0.14.0) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets>=2.21.0->trl==0.14.0) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets>=2.21.0->trl==0.14.0) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets>=2.21.0->trl==0.14.0) (2024.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.21.0->trl==0.14.0) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.11/site-packages (from yarl<2.0,>=1.0->aiohttp->datasets>=2.21.0->trl==0.14.0) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch>=2.0.0->accelerate>=0.34.0->trl==0.14.0) (3.0.2)
# Using cached trl-0.14.0-py3-none-any.whl (313 kB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Using cached multiprocess-0.70.16-py311-none-any.whl (143 kB)
# Installing collected packages: dill, multiprocess, trl
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.9
#     Uninstalling dill-0.3.9:
#       Successfully uninstalled dill-0.3.9
#   Attempting uninstall: multiprocess
#     Found existing installation: multiprocess 0.70.17
#     Uninstalling multiprocess-0.70.17:
#       Successfully uninstalled multiprocess-0.70.17
#   Attempting uninstall: trl
#     Found existing installation: trl 0.15.0.dev0
#     Uninstalling trl-0.15.0.dev0:
#       Successfully uninstalled trl-0.15.0.dev0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pathos 0.3.3 requires dill>=0.3.9, but you have dill 0.3.8 which is incompatible.
# pathos 0.3.3 requires multiprocess>=0.70.17, but you have multiprocess 0.70.16 which is incompatible.
# Successfully installed dill-0.3.8 multiprocess-0.70.16 trl-0.14.0
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: unsloth in /opt/conda/lib/python3.11/site-packages (2025.2.4)
# Requirement already satisfied: vllm in /opt/conda/lib/python3.11/site-packages (0.7.2)
# Requirement already satisfied: unsloth_zoo>=2025.2.1 in /opt/conda/lib/python3.11/site-packages (from unsloth) (2025.2.3)
# Requirement already satisfied: torch>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from unsloth) (2.5.1)
# Requirement already satisfied: xformers>=0.0.27.post2 in /opt/conda/lib/python3.11/site-packages (from unsloth) (0.0.28.post3)
# Requirement already satisfied: bitsandbytes in /opt/conda/lib/python3.11/site-packages (from unsloth) (0.45.2)
# Requirement already satisfied: triton>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from unsloth) (3.1.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from unsloth) (24.2)
# Requirement already satisfied: tyro in /opt/conda/lib/python3.11/site-packages (from unsloth) (0.9.13)
# Requirement already satisfied: transformers!=4.47.0,>=4.46.1 in /opt/conda/lib/python3.11/site-packages (from unsloth) (4.48.2)
# Requirement already satisfied: datasets>=2.16.0 in /opt/conda/lib/python3.11/site-packages (from unsloth) (3.2.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /opt/conda/lib/python3.11/site-packages (from unsloth) (0.2.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from unsloth) (4.67.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.11/site-packages (from unsloth) (5.9.8)
# Requirement already satisfied: wheel>=0.42.0 in /opt/conda/lib/python3.11/site-packages (from unsloth) (0.45.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from unsloth) (1.26.4)
# Requirement already satisfied: accelerate>=0.34.1 in /opt/conda/lib/python3.11/site-packages (from unsloth) (1.3.0)
# Requirement already satisfied: trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9 in /opt/conda/lib/python3.11/site-packages (from unsloth) (0.14.0)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from unsloth) (0.14.0)
# Requirement already satisfied: protobuf<4.0.0 in /opt/conda/lib/python3.11/site-packages (from unsloth) (3.20.3)
# Requirement already satisfied: huggingface_hub in /opt/conda/lib/python3.11/site-packages (from unsloth) (0.28.1)
# Requirement already satisfied: hf_transfer in /opt/conda/lib/python3.11/site-packages (from unsloth) (0.1.9)
# Requirement already satisfied: requests>=2.26.0 in /opt/conda/lib/python3.11/site-packages (from vllm) (2.32.3)
# Requirement already satisfied: blake3 in /opt/conda/lib/python3.11/site-packages (from vllm) (1.0.4)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.11/site-packages (from vllm) (9.0.0)
# Requirement already satisfied: tokenizers>=0.19.1 in /opt/conda/lib/python3.11/site-packages (from vllm) (0.21.0)
# Requirement already satisfied: fastapi!=0.113.*,!=0.114.0,>=0.107.0 in /opt/conda/lib/python3.11/site-packages (from vllm) (0.110.3)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.11/site-packages (from vllm) (3.9.5)
# Requirement already satisfied: openai>=1.52.0 in /opt/conda/lib/python3.11/site-packages (from vllm) (1.61.1)
# Requirement already satisfied: uvicorn[standard] in /opt/conda/lib/python3.11/site-packages (from vllm) (0.30.6)
# Requirement already satisfied: pydantic>=2.9 in /opt/conda/lib/python3.11/site-packages (from vllm) (2.9.2)
# Requirement already satisfied: prometheus_client>=0.18.0 in /opt/conda/lib/python3.11/site-packages (from vllm) (0.21.0)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.11/site-packages (from vllm) (11.1.0)
# Requirement already satisfied: prometheus-fastapi-instrumentator>=7.0.0 in /opt/conda/lib/python3.11/site-packages (from vllm) (7.0.2)
# Requirement already satisfied: tiktoken>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from vllm) (0.7.0)
# Requirement already satisfied: lm-format-enforcer<0.11,>=0.10.9 in /opt/conda/lib/python3.11/site-packages (from vllm) (0.10.9)
# Requirement already satisfied: outlines==0.1.11 in /opt/conda/lib/python3.11/site-packages (from vllm) (0.1.11)
# Requirement already satisfied: lark==1.2.2 in /opt/conda/lib/python3.11/site-packages (from vllm) (1.2.2)
# Requirement already satisfied: xgrammar>=0.1.6 in /opt/conda/lib/python3.11/site-packages (from vllm) (0.1.11)
# Requirement already satisfied: typing_extensions>=4.10 in /opt/conda/lib/python3.11/site-packages (from vllm) (4.12.2)
# Requirement already satisfied: filelock>=3.16.1 in /opt/conda/lib/python3.11/site-packages (from vllm) (3.16.1)
# Requirement already satisfied: partial-json-parser in /opt/conda/lib/python3.11/site-packages (from vllm) (0.2.1.1.post5)
# Requirement already satisfied: pyzmq in /opt/conda/lib/python3.11/site-packages (from vllm) (26.2.0)
# Requirement already satisfied: msgspec in /opt/conda/lib/python3.11/site-packages (from vllm) (0.19.0)
# Requirement already satisfied: gguf==0.10.0 in /opt/conda/lib/python3.11/site-packages (from vllm) (0.10.0)
# Requirement already satisfied: importlib_metadata in /opt/conda/lib/python3.11/site-packages (from vllm) (6.10.0)
# Requirement already satisfied: mistral_common>=1.5.0 in /opt/conda/lib/python3.11/site-packages (from mistral_common[opencv]>=1.5.0->vllm) (1.5.2)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from vllm) (6.0.2)
# Requirement already satisfied: einops in /opt/conda/lib/python3.11/site-packages (from vllm) (0.8.0)
# Requirement already satisfied: compressed-tensors==0.9.1 in /opt/conda/lib/python3.11/site-packages (from vllm) (0.9.1)
# Requirement already satisfied: depyf==0.18.0 in /opt/conda/lib/python3.11/site-packages (from vllm) (0.18.0)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.11/site-packages (from vllm) (2.2.1)
# Requirement already satisfied: ray>=2.9 in /opt/conda/lib/python3.11/site-packages (from ray[default]>=2.9->vllm) (2.37.0)
# Requirement already satisfied: nvidia-ml-py>=12.560.30 in /opt/conda/lib/python3.11/site-packages (from vllm) (12.570.86)
# Requirement already satisfied: torchaudio==2.5.1 in /opt/conda/lib/python3.11/site-packages (from vllm) (2.5.1)
# Requirement already satisfied: torchvision==0.20.1 in /opt/conda/lib/python3.11/site-packages (from vllm) (0.20.1)
# Requirement already satisfied: astor in /opt/conda/lib/python3.11/site-packages (from depyf==0.18.0->vllm) (0.8.1)
# Requirement already satisfied: dill in /opt/conda/lib/python3.11/site-packages (from depyf==0.18.0->vllm) (0.3.8)
# Requirement already satisfied: interegular in /opt/conda/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (0.3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (3.1.4)
# Requirement already satisfied: nest_asyncio in /opt/conda/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (1.6.0)
# Requirement already satisfied: diskcache in /opt/conda/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (5.6.3)
# Requirement already satisfied: referencing in /opt/conda/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (0.35.1)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (4.23.0)
# Requirement already satisfied: pycountry in /opt/conda/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (24.6.1)
# Requirement already satisfied: airportsdata in /opt/conda/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (20241001)
# Requirement already satisfied: outlines_core==0.1.26 in /opt/conda/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (0.1.26)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (3.4.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (12.4.127)
# Requirement already satisfied: sympy==1.13.1 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy==1.13.1->torch>=2.4.0->unsloth) (1.3.0)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/conda/lib/python3.11/site-packages (from accelerate>=0.34.1->unsloth) (0.4.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.11/site-packages (from datasets>=2.16.0->unsloth) (15.0.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from datasets>=2.16.0->unsloth) (2.2.3)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.11/site-packages (from datasets>=2.16.0->unsloth) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /opt/conda/lib/python3.11/site-packages (from datasets>=2.16.0->unsloth) (0.70.16)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /opt/conda/lib/python3.11/site-packages (from fastapi!=0.113.*,!=0.114.0,>=0.107.0->vllm) (0.37.2)
# Collecting pillow (from vllm)
#   Using cached pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: opencv-python-headless<5.0.0,>=4.0.0 in /opt/conda/lib/python3.11/site-packages (from mistral_common[opencv]>=1.5.0->vllm) (4.11.0.86)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/lib/python3.11/site-packages (from openai>=1.52.0->vllm) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.11/site-packages (from openai>=1.52.0->vllm) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.11/site-packages (from openai>=1.52.0->vllm) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from openai>=1.52.0->vllm) (0.8.2)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.11/site-packages (from openai>=1.52.0->vllm) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.9->vllm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.9->vllm) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.26.0->vllm) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.26.0->vllm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.26.0->vllm) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.26.0->vllm) (2024.8.30)
# Requirement already satisfied: regex>=2022.1.18 in /opt/conda/lib/python3.11/site-packages (from tiktoken>=0.6.0->vllm) (2024.11.6)
# Requirement already satisfied: rich in /opt/conda/lib/python3.11/site-packages (from trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (13.9.4)
# Requirement already satisfied: cut_cross_entropy in /opt/conda/lib/python3.11/site-packages (from unsloth_zoo>=2025.2.1->unsloth) (25.1.1)
# Requirement already satisfied: pybind11 in /opt/conda/lib/python3.11/site-packages (from xgrammar>=0.1.6->vllm) (2.13.6)
# Requirement already satisfied: pytest in /opt/conda/lib/python3.11/site-packages (from xgrammar>=0.1.6->vllm) (8.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp->vllm) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->vllm) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp->vllm) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp->vllm) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->vllm) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib_metadata->vllm) (3.21.0)
# Requirement already satisfied: docstring-parser>=0.15 in /opt/conda/lib/python3.11/site-packages (from tyro->unsloth) (0.16)
# Requirement already satisfied: shtab>=1.5.6 in /opt/conda/lib/python3.11/site-packages (from tyro->unsloth) (1.7.1)
# Requirement already satisfied: typeguard>=4.0.0 in /opt/conda/lib/python3.11/site-packages (from tyro->unsloth) (4.4.1)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.11/site-packages (from uvicorn[standard]->vllm) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.11/site-packages (from uvicorn[standard]->vllm) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /opt/conda/lib/python3.11/site-packages (from uvicorn[standard]->vllm) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/conda/lib/python3.11/site-packages (from uvicorn[standard]->vllm) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/conda/lib/python3.11/site-packages (from uvicorn[standard]->vllm) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /opt/conda/lib/python3.11/site-packages (from uvicorn[standard]->vllm) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in /opt/conda/lib/python3.11/site-packages (from uvicorn[standard]->vllm) (14.2)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai>=1.52.0->vllm) (1.0.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema->outlines==0.1.11->vllm) (2024.10.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema->outlines==0.1.11->vllm) (0.21.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (2.18.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.11/site-packages (from yarl<2.0,>=1.0->aiohttp->vllm) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->outlines==0.1.11->vllm) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets>=2.16.0->unsloth) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets>=2.16.0->unsloth) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets>=2.16.0->unsloth) (2024.2)
# Requirement already satisfied: iniconfig in /opt/conda/lib/python3.11/site-packages (from pytest->xgrammar>=0.1.6->vllm) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /opt/conda/lib/python3.11/site-packages (from pytest->xgrammar>=0.1.6->vllm) (1.5.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth) (1.16.0)
# Using cached pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
# Installing collected packages: pillow
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-multimodal 1.1.1 requires nvidia-ml-py3==7.352.0, which is not installed.
# autogluon-multimodal 1.1.1 requires accelerate<0.22.0,>=0.21.0, but you have accelerate 1.3.0 which is incompatible.
# autogluon-multimodal 1.1.1 requires jsonschema<4.22,>=4.18, but you have jsonschema 4.23.0 which is incompatible.
# autogluon-multimodal 1.1.1 requires omegaconf<2.3.0,>=2.1.1, but you have omegaconf 2.3.0 which is incompatible.
# autogluon-multimodal 1.1.1 requires scikit-learn<1.4.1,>=1.3.0, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-multimodal 1.1.1 requires torch<2.4,>=2.2, but you have torch 2.5.1 which is incompatible.
# autogluon-multimodal 1.1.1 requires torchvision<0.20.0,>=0.16.0, but you have torchvision 0.20.1 which is incompatible.
# autogluon-multimodal 1.1.1 requires transformers[sentencepiece]<4.41.0,>=4.38.0, but you have transformers 4.48.2 which is incompatible.
# Successfully installed pillow-10.4.0
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.11/site-packages (10.4.0)
# Collecting pillow
#   Using cached pillow-11.1.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: diffusers in /opt/conda/lib/python3.11/site-packages (0.32.2)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.11/site-packages (from diffusers) (6.10.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from diffusers) (3.16.1)
# Requirement already satisfied: huggingface-hub>=0.23.2 in /opt/conda/lib/python3.11/site-packages (from diffusers) (0.28.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.11/site-packages (from diffusers) (2024.11.6)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from diffusers) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.11/site-packages (from diffusers) (0.4.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.23.2->diffusers) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.23.2->diffusers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.23.2->diffusers) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.23.2->diffusers) (4.67.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.23.2->diffusers) (4.12.2)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib-metadata->diffusers) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->diffusers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->diffusers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->diffusers) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->diffusers) (2024.8.30)
# Using cached pillow-11.1.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
# Installing collected packages: pillow
#   Attempting uninstall: pillow
#     Found existing installation: pillow 10.4.0
#     Uninstalling pillow-10.4.0:
#       Successfully uninstalled pillow-10.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-multimodal 1.1.1 requires nvidia-ml-py3==7.352.0, which is not installed.
# autogluon-multimodal 1.1.1 requires accelerate<0.22.0,>=0.21.0, but you have accelerate 1.3.0 which is incompatible.
# autogluon-multimodal 1.1.1 requires jsonschema<4.22,>=4.18, but you have jsonschema 4.23.0 which is incompatible.
# autogluon-multimodal 1.1.1 requires omegaconf<2.3.0,>=2.1.1, but you have omegaconf 2.3.0 which is incompatible.
# autogluon-multimodal 1.1.1 requires Pillow<11,>=10.0.1, but you have pillow 11.1.0 which is incompatible.
# autogluon-multimodal 1.1.1 requires scikit-learn<1.4.1,>=1.3.0, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-multimodal 1.1.1 requires torch<2.4,>=2.2, but you have torch 2.5.1 which is incompatible.
# autogluon-multimodal 1.1.1 requires torchvision<0.20.0,>=0.16.0, but you have torchvision 0.20.1 which is incompatible.
# autogluon-multimodal 1.1.1 requires transformers[sentencepiece]<4.41.0,>=4.38.0, but you have transformers 4.48.2 which is incompatible.
# mistral-common 1.5.2 requires pillow<11.0.0,>=10.3.0, but you have pillow 11.1.0 which is incompatible.
# Successfully installed pillow-11.1.0

# %%
import datasets
updated_dataset = datasets.load_dataset("w601sxs/processed_simpleCoT_b1ade", split="train")

# %%
# updated_dataset = dataset.map(lambda example: {
#     'prompt': f"context: <You are a useful AI assistant. Use the provided context to provide a rationale, and then answer the question that follows.>\nquestion: <{example['source']}>\n",
#     'completion': f"answer: <{example['rationale']}\n{example['target']}>" 
# })

# %%
# updated_dataset = updated_dataset.remove_columns(['source', 'target', 'rationale', 'task', 'type'])

# %%
# %pip install -U "huggingface_hub[cli]"

# %%
# updated_dataset.push_to_hub("w601sxs/processed_simpleCoT_b1ade")

# %%
# %pip install --upgrade transformers peft trl sentence_transformers vllm rouge

# %%
## Patching RL
from unsloth import FastLanguageModel, PatchFastRL
PatchFastRL("GRPO", FastLanguageModel)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2025-02-07 04:12:23.452120: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-07 04:12:23.468388: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-07 04:12:23.473497: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-07 04:12:23.486002: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 02-07 04:12:28 __init__.py:190] Automatically detected platform cuda.

# %%
from unsloth import is_bfloat16_supported
import torch
max_seq_length = 4096 # Can increase for longer reasoning traces
lora_rank = 16 # Larger rank = smarter, but slower

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "meta-llama/Llama-3.2-1B-Instruct",
    max_seq_length = max_seq_length,
    load_in_4bit = True, # False for LoRA 16bit
    fast_inference = True, # Enable vLLM fast inference
    max_lora_rank = lora_rank,
    gpu_memory_utilization = 0.7, # Reduce if out of memory
)

model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ], # Remove QKVO if out of memory
    lora_alpha = lora_rank,
    use_gradient_checkpointing = "unsloth", # Enable long context finetuning
    random_state = 340,
)
# Out:
# ==((====))==  Unsloth 2025.2.4: Fast Llama patching. Transformers: 4.48.2.
#    \\   /|    GPU: NVIDIA A10G. Max memory: 21.975 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.6. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: vLLM loading unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit with actual GPU utilization = 69.2%
# Unsloth: Your GPU has CUDA compute capability 8.6 with VRAM = 21.98 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 4096. Num Sequences = 256.
# Unsloth: vLLM's KV Cache can use up to 14.13 GB. Also swap space = 6 GB.
# INFO 02-10 18:02:43 config.py:542] This model supports multiple tasks: {'embed', 'reward', 'classify', 'generate', 'score'}. Defaulting to 'generate'.
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'bfloat16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['lm_head', 'multi_modal_projector', 'merger', 'modality_projection', 'model.layers.1.mlp'], 'llm_int8_threshold': 6.0}
# INFO 02-10 18:02:43 llm_engine.py:234] Initializing a V0 LLM engine (v0.7.2) with config: model='unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit', speculative_config=None, tokenizer='unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=4096, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":0,"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":256}, use_cached_outputs=False,
# INFO 02-10 18:02:44 cuda.py:230] Using Flash Attention backend.
# INFO 02-10 18:02:45 model_runner.py:1110] Starting to load model unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit...
# INFO 02-10 18:02:45 loader.py:1102] Loading weights with BitsAndBytes quantization.  May take a while ...
# [W210 18:02:45.838752100 CUDAAllocatorConfig.h:28] Warning: expandable_segments not supported on this platform (function operator())
# INFO 02-10 18:02:45 weight_utils.py:252] Using model weights format ['*.safetensors']
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 02-10 18:02:47 model_runner.py:1115] Loading model weights took 1.0453 GB
# INFO 02-10 18:02:47 punica_selector.py:18] Using PunicaWrapperGPU.
# INFO 02-10 18:02:51 worker.py:267] Memory profiling takes 2.46 seconds
# INFO 02-10 18:02:51 worker.py:267] the current vLLM instance can use total_gpu_memory (21.98GiB) x gpu_memory_utilization (0.69) = 15.21GiB
# INFO 02-10 18:02:51 worker.py:267] model weights take 1.05GiB; non_torch_memory takes 0.06GiB; PyTorch activation peak memory takes 1.20GiB; the rest of the memory reserved for KV Cache is 12.91GiB.
# INFO 02-10 18:02:53 executor_base.py:110] # CUDA blocks: 26440, # CPU blocks: 12288
# INFO 02-10 18:02:53 executor_base.py:115] Maximum concurrency for 4096 tokens per request: 103.28x
# INFO 02-10 18:02:57 model_runner.py:1434] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes: 100%|██████████| 35/35 [01:24<00:00,  2.41s/it]
# INFO 02-10 18:04:22 model_runner.py:1562] Graph capturing finished in 85 secs, took 0.45 GiB
# INFO 02-10 18:04:22 llm_engine.py:431] init engine (profile, create kv cache, warmup model) took 94.70 seconds
# Unsloth 2025.2.4 patched 16 layers with 16 QKV layers, 16 O layers and 16 MLP layers.

# %%
from datasets import load_dataset
from peft import LoraConfig
from trl import GRPOConfig, GRPOTrainer
import pandas as pd
from sentence_transformers import SentenceTransformer
# emodel = SentenceTransformer("w601sxs/b1ade-embed", device='cuda')
import re
import time
import re
import torch
from rouge import Rouge 

def correctness_reward_func(prompts, completions, answer, **kwargs) -> list[float]:
    responses = [completion[0]['content'] for completion in completions]
    q = prompts[0][-1]['content']
    extracted_responses = [extract_content(r) for r in responses]

    rouge = Rouge()
    
    scores = [s["rouge-l"]["f"] for s in rouge.get_scores(extracted_responses, answer)]
    
    # print('-'*20, f"Question:\n{q}", f"\nAnswer:\n{answer[0]}", f"\nResponse:\n{responses[0]}", f"\nExtracted:\n{extracted_responses[0]}")
    return scores
    

def format_reward_func(prompts,completions):
    """Reward function that checks if the completion has a specific format."""
    pattern = r'^answer: <.*>$'
    matches = [re.match(pattern, content, re.DOTALL) for content in completions]
    return [1.0 if match else 0.0 for match in matches]

def len_reward_func(prompts,completions):

    len_reward = [len(c)/1024. for c in completions]
    return len_reward

def reward_func(prompts, completions): ## use array instead
    """Reward function that gives higher scores to longer completions."""
    format_reward = torch.Tensor(format_reward_func(completions))

    len_reward = [len(c)/1024. for c in completions]
    
    return answer_similarity(prompts, completions)*format_reward*len_reward

# Load the dataset
updated_dataset = load_dataset("w601sxs/processed_simpleCoT_b1ade", split="train")

def extract_content(text):
    match = re.match(r'^answer: <(.*)>$', text, re.DOTALL)
    return match.group(1) if match else text

df = updated_dataset.to_pandas()

def answer_similarity(prompts, completions):
    # Extract ground truth completions
    
    ground_truth_completions = []
    for prompt in prompts:
        row = df.loc[df['prompt'] == prompt]
        if not row.empty:
            gtcompletion = row['completion'].iloc[0]
            ground_truth_completions.append(extract_content(gtcompletion))
        else:
            ground_truth_completions.append(None)
    
    
    # Process input completions
    processed_completions = [extract_content(comp) for comp in completions]
    
    # Filter out None values
    # valid_mask = [gt is not None for gt in ground_truth_completions]
    # valid_ground_truth = [gt for gt in ground_truth_completions if gt is not None]
    # valid_completions = [comp for comp, keep in zip(processed_completions, valid_mask) if keep]

    # # Calculate embeddings and similarities
    # completion_embeddings = emodel.encode(valid_completions)
    # ground_truth_embeddings = emodel.encode(valid_ground_truth)
    # similarities = emodel.similarity(completion_embeddings, ground_truth_embeddings).diagonal()

    rouge = Rouge()
    # print(processed_completions)
    # print("___")
    # print(ground_truth_completions)
    
    scores = [s["rouge-l"]["f"] for s in rouge.get_scores(processed_completions, ground_truth_completions)]

    
    
    return scores #similarities


from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    use_vllm = True, # use vLLM for fast inference!
    learning_rate = 5e-6,
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.1,
    warmup_ratio = 0.1,
    lr_scheduler_type = "cosine",
    optim = "paged_adamw_8bit",
    logging_steps = 1,
    bf16 = is_bfloat16_supported(),
    fp16 = not is_bfloat16_supported(),
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 1, # Increase to 4 for smoother training
    num_generations = 6, # Decrease if out of memory
    max_prompt_length = 4096,
    max_completion_length = 1024,
    num_train_epochs = 3, # Set to 1 for a full training run
    # max_steps = 250,
    save_steps = 250,
    max_grad_norm = 0.1,
    report_to = "wandb", # Can use Weights & Biases
    output_dir = "outputs_b1ade_1B_GRPO",
)

trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [answer_similarity, format_reward_func, len_reward_func],
    args = training_args,
    train_dataset = updated_dataset,
)

trainer.train()
# Out:
# torch.distributed process group is initialized, but parallel_mode != ParallelMode.DISTRIBUTED. In order to use Torch DDP, launch your script with `python -m torch.distributed.launch
# [2025-02-10 18:06:21,698] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: cannot find -laio: No such file or directory
# collect2: error: ld returned 1 exit status
# /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: cannot find -laio: No such file or directory
# collect2: error: ld returned 1 exit status
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 2,214,941 | Num Epochs = 3
# O^O/ \_/ \    Batch size per device = 1 | Gradient Accumulation steps = 1
# \        /    Total batch size = 1 | Total steps = 6,644,823
#  "-____-"     Number of trainable parameters = 11,272,192
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Currently logged in as: w601sxs (w601sxs-aws) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/home/sagemaker-user/wandb/run-20250210_180628-7qi5w0ge</code>
# Syncing run <strong><a href='https://wandb.ai/w601sxs-aws/huggingface/runs/7qi5w0ge' target="_blank">outputs_b1ade_1B_GRPO</a></strong> to <a href='https://wandb.ai/w601sxs-aws/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/w601sxs-aws/huggingface' target="_blank">https://wandb.ai/w601sxs-aws/huggingface</a>
#  View run at <a href='https://wandb.ai/w601sxs-aws/huggingface/runs/7qi5w0ge' target="_blank">https://wandb.ai/w601sxs-aws/huggingface/runs/7qi5w0ge</a>
#     <div>
#
#       <progress value='2' max='6644823' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [      2/6644823 : < :, Epoch 0.00/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completion_length</th>
#       <th>kl</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[33], line 126
#      93 training_args = GRPOConfig(
#      94     use_vllm = True, # use vLLM for fast inference!
#      95     learning_rate = 5e-6,
#    (...)
#     115     output_dir = "outputs_b1ade_1B_GRPO",
#     116 )
#     118 trainer = GRPOTrainer(
#     119     model = model,
#     120     processing_class = tokenizer,
#    (...)
#     123     train_dataset = updated_dataset,
#     124 )
# --> 126 trainer.train()
#
# File /opt/conda/lib/python3.11/site-packages/transformers/trainer.py:2171, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2169         hf_hub_utils.enable_progress_bars()
#    2170 else:
# -> 2171     return inner_training_loop(
#    2172         args=args,
#    2173         resume_from_checkpoint=resume_from_checkpoint,
#    2174         trial=trial,
#    2175         ignore_keys_for_eval=ignore_keys_for_eval,
#    2176     )
#
# File <string>:382, in _fast_inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#
# File <string>:68, in _unsloth_training_step(***failed resolving arguments***)
#
# File /opt/conda/lib/python3.11/site-packages/accelerate/accelerator.py:2246, in Accelerator.backward(self, loss, **kwargs)
#    2244     self.lomo_backward(loss, learning_rate)
#    2245 else:
# -> 2246     loss.backward(**kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File /opt/conda/lib/python3.11/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File /opt/conda/lib/python3.11/site-packages/torch/autograd/graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 504.00 MiB. GPU 0 has a total capacity of 21.98 GiB of which 172.44 MiB is free. Process 115727 has 21.78 GiB memory in use. Of the allocated memory 20.93 GiB is allocated by PyTorch, with 66.00 MiB allocated in private pools (e.g., CUDA Graphs), and 182.51 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %% [markdown]
# ## Newer file

# %%
# %%writefile train_grpo_v2.py
from datasets import load_dataset
from peft import LoraConfig
from trl import GRPOConfig, GRPOTrainer
import pandas as pd
from sentence_transformers import SentenceTransformer
from unsloth import FastLanguageModel, PatchFastRL
# emodel = SentenceTransformer("w601sxs/b1ade-embed", device='cuda')
import re
import time
import re
import torch
from rouge import Rouge 
from unsloth import is_bfloat16_supported
import torch
max_seq_length = 4096 # Can increase for longer reasoning traces
lora_rank = 8 # Larger rank = smarter, but slower

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "meta-llama/Llama-3.2-1B-Instruct",
    max_seq_length = max_seq_length,
    load_in_4bit = True, # False for LoRA 16bit
    fast_inference = True, # Enable vLLM fast inference
    max_lora_rank = lora_rank,
    gpu_memory_utilization = 0.7, # Reduce if out of memory
)

model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ], # Remove QKVO if out of memory
    lora_alpha = lora_rank,
    use_gradient_checkpointing = "unsloth", # Enable long context finetuning
    random_state = 340,
)

def correctness_reward_func(prompts, completions, answer, **kwargs) -> list[float]:
    responses = [completion[0]['content'] for completion in completions]
    q = prompts[0][-1]['content']
    extracted_responses = [extract_content(r) for r in responses]

    rouge = Rouge()
    
    scores = [s["rouge-l"]["f"] for s in rouge.get_scores(extracted_responses, answer)]
    
    # print('-'*20, f"Question:\n{q}", f"\nAnswer:\n{answer[0]}", f"\nResponse:\n{responses[0]}", f"\nExtracted:\n{extracted_responses[0]}")
    return scores
    

def format_reward_func(prompts,completions):
    """Reward function that checks if the completion has a specific format."""
    pattern = r'^answer: <.*>$'
    matches = [re.match(pattern, content, re.DOTALL) for content in completions]
    return [1.0 if match else 0.0 for match in matches]

def len_reward_func(prompts,completions):

    len_reward = [len(c)/1024. for c in completions]
    return len_reward

def reward_func(prompts, completions): ## use array instead
    """Reward function that gives higher scores to longer completions."""
    format_reward = torch.Tensor(format_reward_func(completions))

    len_reward = [len(c)/1024. for c in completions]
    
    return answer_similarity(prompts, completions)*format_reward*len_reward

# Load the dataset
updated_dataset = load_dataset("w601sxs/processed_simpleCoT_b1ade", split="train")

def extract_content(text):
    match = re.match(r'^answer: <(.*)>$', text, re.DOTALL)
    return match.group(1) if match else text

df = updated_dataset.to_pandas()

def answer_similarity(prompts, completions):
    # Extract ground truth completions
    
    ground_truth_completions = []
    for prompt in prompts:
        row = df.loc[df['prompt'] == prompt]
        if not row.empty:
            gtcompletion = row['completion'].iloc[0]
            ground_truth_completions.append(extract_content(gtcompletion))
        else:
            ground_truth_completions.append(None)
    
    
    # Process input completions
    processed_completions = [extract_content(comp) for comp in completions]
    
    # Filter out None values
    # valid_mask = [gt is not None for gt in ground_truth_completions]
    # valid_ground_truth = [gt for gt in ground_truth_completions if gt is not None]
    # valid_completions = [comp for comp, keep in zip(processed_completions, valid_mask) if keep]

    # # Calculate embeddings and similarities
    # completion_embeddings = emodel.encode(valid_completions)
    # ground_truth_embeddings = emodel.encode(valid_ground_truth)
    # similarities = emodel.similarity(completion_embeddings, ground_truth_embeddings).diagonal()

    rouge = Rouge()
    # print(processed_completions)
    # print("___")
    # print(ground_truth_completions)
    
    scores = [s["rouge-l"]["f"] for s in rouge.get_scores(processed_completions, ground_truth_completions)]

    
    
    return scores #similarities


from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    use_vllm = True, # use vLLM for fast inference!
    vllm_device= "auto",
    vllm_gpu_memory_utilization= 0.6,
    learning_rate = 5e-6,
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.1,
    warmup_ratio = 0.1,
    lr_scheduler_type = "cosine",
    optim = "paged_adamw_8bit",
    logging_steps = 1,
    bf16 = is_bfloat16_supported(),
    fp16 = not is_bfloat16_supported(),
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 1, # Increase to 4 for smoother training
    num_generations = 4, # Decrease if out of memory
    max_prompt_length = 2048,
    max_completion_length = 256,
    num_train_epochs = 3, # Set to 1 for a full training run
    # max_steps = 250,
    save_steps = 250,
    max_grad_norm = 0.1,
    report_to = "wandb", # Can use Weights & Biases
    output_dir = "outputs_b1ade_1B_GRPO",
)

trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [answer_similarity, format_reward_func, len_reward_func],
    args = training_args,
    train_dataset = updated_dataset,
)
trainer.train()
# Out:
# Writing train_grpo_v2.py

# %%
# %%writefile config_deepspeed.yaml
# compute_environment: LOCAL_MACHINE
# deepspeed_config:
#   gradient_accumulation_steps: 1
#   gradient_clipping: 1.0
#   offload_optimizer_device: cpu
#   offload_param_device: cpu
#   zero3_init_flag: true
#   zero3_save_16bit_model: true
#   zero_stage: 3
# distributed_type: DEEPSPEED
# fsdp_config: {}
# machine_rank: 0
# main_process_ip: null
# main_process_port: null
# main_training_function: main
# mixed_precision: bf16
# num_machines: 1
# num_processes: 7
# use_cpu: false
# mixed_precision: fp8
# rdzv_backend: static
# same_network: true
# Out:
# Overwriting config_deepspeed.yaml

# %%
# !accelerate launch --num_machines 1 --num_processes 7 --multi_gpu --mixed_precision 'bf16' train_grpo_v2.py
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2025-02-11 15:05:38.582078: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-11 15:05:38.595727: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-11 15:05:38.598254: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-11 15:05:38.603365: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-11 15:05:38.611736: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-11 15:05:38.615360: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-11 15:05:38.616834: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-11 15:05:38.628677: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-11 15:05:38.688236: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-11 15:05:38.704240: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-11 15:05:38.707568: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-11 15:05:38.709255: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-11 15:05:38.721061: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-11 15:05:38.723719: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-11 15:05:38.728833: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-11 15:05:38.732130: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-11 15:05:38.736223: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-11 15:05:38.740772: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-11 15:05:38.748391: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-11 15:05:38.752495: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-11 15:05:38.753510: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-11 15:05:38.757587: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-11 15:05:38.765356: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-11 15:05:38.769734: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-11 15:05:39.032960: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-11 15:05:39.049131: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-11 15:05:39.054248: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-11 15:05:39.066089: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [2025-02-11 15:05:43,632] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-02-11 15:05:43,816] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-02-11 15:05:43,817] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-02-11 15:05:43,818] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-02-11 15:05:43,820] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-02-11 15:05:43,833] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-02-11 15:05:43,833] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# INFO 02-11 15:05:46 __init__.py:190] Automatically detected platform cuda.
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# INFO 02-11 15:05:46 __init__.py:190] Automatically detected platform cuda.
# INFO 02-11 15:05:47 __init__.py:190] Automatically detected platform cuda.
# INFO 02-11 15:05:47 __init__.py:190] Automatically detected platform cuda.
# INFO 02-11 15:05:47 __init__.py:190] Automatically detected platform cuda.
# INFO 02-11 15:05:47 __init__.py:190] Automatically detected platform cuda.
# INFO 02-11 15:05:47 __init__.py:190] Automatically detected platform cuda.
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/tokenizer_utils.py", line 1061, in <module>
#     exec(trainer_text, globals())
#   File "<string>", line 4
#     model = <class 'inspect._empty'>,
#             ^
# SyntaxError: invalid syntax
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sagemaker-user/train_grpo_v2.py", line 6, in <module>
#     from unsloth import FastLanguageModel, PatchFastRL
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/__init__.py", line 212, in <module>
#     from .models import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/__init__.py", line 16, in <module>
#     from .granite import FastGraniteModel
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/granite.py", line 15, in <module>
#     from .llama import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/llama.py", line 36, in <module>
#     from ..tokenizer_utils import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/tokenizer_utils.py", line 1063, in <module>
#     raise RuntimeError(f"Unsloth: Please file a bug report! Error patching {trainer_name}")
# RuntimeError: Unsloth: Please file a bug report! Error patching SFTTrainer
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/tokenizer_utils.py", line 1061, in <module>
#     exec(trainer_text, globals())
#   File "<string>", line 4
#     model = <class 'inspect._empty'>,
#             ^
# SyntaxError: invalid syntax
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sagemaker-user/train_grpo_v2.py", line 6, in <module>
#     from unsloth import FastLanguageModel, PatchFastRL
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/__init__.py", line 212, in <module>
#     from .models import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/__init__.py", line 16, in <module>
#     from .granite import FastGraniteModel
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/granite.py", line 15, in <module>
#     from .llama import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/llama.py", line 36, in <module>
#     from ..tokenizer_utils import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/tokenizer_utils.py", line 1063, in <module>
#     raise RuntimeError(f"Unsloth: Please file a bug report! Error patching {trainer_name}")
# RuntimeError: Unsloth: Please file a bug report! Error patching SFTTrainer
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/tokenizer_utils.py", line 1061, in <module>
#     exec(trainer_text, globals())
#   File "<string>", line 4
#     model = <class 'inspect._empty'>,
#             ^
# SyntaxError: invalid syntax
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sagemaker-user/train_grpo_v2.py", line 6, in <module>
#     from unsloth import FastLanguageModel, PatchFastRL
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/__init__.py", line 212, in <module>
#     from .models import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/__init__.py", line 16, in <module>
#     from .granite import FastGraniteModel
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/granite.py", line 15, in <module>
#     from .llama import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/llama.py", line 36, in <module>
#     from ..tokenizer_utils import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/tokenizer_utils.py", line 1063, in <module>
#     raise RuntimeError(f"Unsloth: Please file a bug report! Error patching {trainer_name}")
# RuntimeError: Unsloth: Please file a bug report! Error patching SFTTrainer
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/tokenizer_utils.py", line 1061, in <module>
#     exec(trainer_text, globals())
#   File "<string>", line 4
#     model = <class 'inspect._empty'>,
#             ^
# SyntaxError: invalid syntax
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sagemaker-user/train_grpo_v2.py", line 6, in <module>
#     from unsloth import FastLanguageModel, PatchFastRL
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/__init__.py", line 212, in <module>
#     from .models import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/__init__.py", line 16, in <module>
#     from .granite import FastGraniteModel
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/granite.py", line 15, in <module>
#     from .llama import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/llama.py", line 36, in <module>
#     from ..tokenizer_utils import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/tokenizer_utils.py", line 1063, in <module>
#     raise RuntimeError(f"Unsloth: Please file a bug report! Error patching {trainer_name}")
# RuntimeError: Unsloth: Please file a bug report! Error patching SFTTrainer
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/tokenizer_utils.py", line 1061, in <module>
#     exec(trainer_text, globals())
#   File "<string>", line 4
#     model = <class 'inspect._empty'>,
#             ^
# SyntaxError: invalid syntax
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sagemaker-user/train_grpo_v2.py", line 6, in <module>
#     from unsloth import FastLanguageModel, PatchFastRL
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/__init__.py", line 212, in <module>
#     from .models import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/__init__.py", line 16, in <module>
#     from .granite import FastGraniteModel
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/granite.py", line 15, in <module>
#     from .llama import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/llama.py", line 36, in <module>
#     from ..tokenizer_utils import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/tokenizer_utils.py", line 1063, in <module>
#     raise RuntimeError(f"Unsloth: Please file a bug report! Error patching {trainer_name}")
# RuntimeError: Unsloth: Please file a bug report! Error patching SFTTrainer
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/tokenizer_utils.py", line 1061, in <module>
#     exec(trainer_text, globals())
#   File "<string>", line 4
#     model = <class 'inspect._empty'>,
#             ^
# SyntaxError: invalid syntax
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sagemaker-user/train_grpo_v2.py", line 6, in <module>
#     from unsloth import FastLanguageModel, PatchFastRL
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/__init__.py", line 212, in <module>
#     from .models import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/__init__.py", line 16, in <module>
#     from .granite import FastGraniteModel
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/granite.py", line 15, in <module>
#     from .llama import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/llama.py", line 36, in <module>
#     from ..tokenizer_utils import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/tokenizer_utils.py", line 1063, in <module>
#     raise RuntimeError(f"Unsloth: Please file a bug report! Error patching {trainer_name}")
# RuntimeError: Unsloth: Please file a bug report! Error patching SFTTrainer
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/tokenizer_utils.py", line 1061, in <module>
#     exec(trainer_text, globals())
#   File "<string>", line 4
#     model = <class 'inspect._empty'>,
#             ^
# SyntaxError: invalid syntax
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sagemaker-user/train_grpo_v2.py", line 6, in <module>
#     from unsloth import FastLanguageModel, PatchFastRL
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/__init__.py", line 212, in <module>
#     from .models import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/__init__.py", line 16, in <module>
#     from .granite import FastGraniteModel
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/granite.py", line 15, in <module>
#     from .llama import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/models/llama.py", line 36, in <module>
#     from ..tokenizer_utils import *
#   File "/opt/conda/lib/python3.11/site-packages/unsloth/tokenizer_utils.py", line 1063, in <module>
#     raise RuntimeError(f"Unsloth: Please file a bug report! Error patching {trainer_name}")
# RuntimeError: Unsloth: Please file a bug report! Error patching SFTTrainer
# W0211 15:05:53.136000 169305 site-packages/torch/distributed/elastic/multiprocessing/api.py:897] Sending process 169453 closing signal SIGTERM
# W0211 15:05:53.136000 169305 site-packages/torch/distributed/elastic/multiprocessing/api.py:897] Sending process 169454 closing signal SIGTERM
# W0211 15:05:53.137000 169305 site-packages/torch/distributed/elastic/multiprocessing/api.py:897] Sending process 169455 closing signal SIGTERM
# W0211 15:05:53.137000 169305 site-packages/torch/distributed/elastic/multiprocessing/api.py:897] Sending process 169456 closing signal SIGTERM
# W0211 15:05:53.137000 169305 site-packages/torch/distributed/elastic/multiprocessing/api.py:897] Sending process 169457 closing signal SIGTERM
# W0211 15:05:53.138000 169305 site-packages/torch/distributed/elastic/multiprocessing/api.py:897] Sending process 169459 closing signal SIGTERM
# E0211 15:05:53.904000 169305 site-packages/torch/distributed/elastic/multiprocessing/api.py:869] failed (exitcode: 1) local_rank: 5 (pid: 169458) of binary: /opt/conda/bin/python
# Traceback (most recent call last):
#   File "/opt/conda/bin/accelerate", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/accelerate/commands/accelerate_cli.py", line 48, in main
#     args.func(args)
#   File "/opt/conda/lib/python3.11/site-packages/accelerate/commands/launch.py", line 1163, in launch_command
#     multi_gpu_launcher(args)
#   File "/opt/conda/lib/python3.11/site-packages/accelerate/commands/launch.py", line 792, in multi_gpu_launcher
#     distrib_run.run(args)
#   File "/opt/conda/lib/python3.11/site-packages/torch/distributed/run.py", line 910, in run
#     elastic_launch(
#   File "/opt/conda/lib/python3.11/site-packages/torch/distributed/launcher/api.py", line 138, in __call__
#     return launch_agent(self._config, self._entrypoint, list(args))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/torch/distributed/launcher/api.py", line 269, in launch_agent
#     raise ChildFailedError(
# torch.distributed.elastic.multiprocessing.errors.ChildFailedError:
# ============================================================
# train_grpo_v2.py FAILED
# ------------------------------------------------------------
# Failures:
#   <NO_OTHER_FAILURES>
# ------------------------------------------------------------
# Root Cause (first observed failure):
# [0]:
#   time      : 2025-02-11_15:05:53
#   host      : default
#   rank      : 5 (local_rank: 5)
#   exitcode  : 1 (pid: 169458)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# ============================================================

# %% [markdown]
# ### Older file

# %%
# %%writefile train_grpo.py
from datasets import load_dataset
from peft import LoraConfig
from trl import GRPOConfig, GRPOTrainer
import pandas as pd
from sentence_transformers import SentenceTransformer
# emodel = SentenceTransformer("w601sxs/b1ade-embed", device='cuda')
import re
import time
import re
import torch
from rouge import Rouge 


def format_reward_func(completions):
    """Reward function that checks if the completion has a specific format."""
    pattern = r'^answer: <.*>$'
    matches = [re.match(pattern, content, re.DOTALL) for content in completions]
    return [1.0 if match else 0.0 for match in matches]

def reward_func(prompts, completions):
    """Reward function that gives higher scores to longer completions."""
    format_reward = torch.Tensor(format_reward_func(completions))
            
    
    return answer_similarity(prompts, completions)*format_reward

# Load the dataset
updated_dataset = load_dataset("w601sxs/processed_simpleCoT_b1ade", split="train")

def extract_content(text):
    match = re.match(r'^answer: <(.*)>$', text, re.DOTALL)
    return match.group(1) if match else text

df = updated_dataset.to_pandas()

def answer_similarity(prompts, completions):
    # Extract ground truth completions
    ground_truth_completions = []
    for prompt in prompts:
        row = df.loc[df['prompt'] == prompt]
        if not row.empty:
            gtcompletion = row['completion'].iloc[0]
            ground_truth_completions.append(extract_content(gtcompletion))
        else:
            ground_truth_completions.append(None)
    
    
    # Process input completions
    processed_completions = [extract_content(comp) for comp in completions]
    
    # Filter out None values
    valid_mask = [gt is not None for gt in ground_truth_completions]
    valid_ground_truth = [gt for gt in ground_truth_completions if gt is not None]
    valid_completions = [comp for comp, keep in zip(processed_completions, valid_mask) if keep]

    # # Calculate embeddings and similarities
    # completion_embeddings = emodel.encode(valid_completions)
    # ground_truth_embeddings = emodel.encode(valid_ground_truth)
    # similarities = emodel.similarity(completion_embeddings, ground_truth_embeddings).diagonal()

    rouge = Rouge()
    scores = [s["rouge-l"]["f"] for s in rouge.get_scores(valid_completions, valid_ground_truth)]
    
    return scores #similarities


training_args = GRPOConfig(
    output_dir="b1ade-1b-GRPO",
    learning_rate=1e-5,
    logging_steps=1,
    max_completion_length=256,
    bf16=True,
    per_device_train_batch_size=1,
    per_device_eval_batch_size=1,
    num_train_epochs=10,
    use_vllm=True,
    vllm_device="auto")

trainer = GRPOTrainer(
    model="w601sxs/b1ade-1b-bf16",
    reward_funcs=reward_func,
    args=training_args,
    train_dataset=updated_dataset,
    peft_config=LoraConfig(task_type="CAUSAL_LM", r=4),
)

trainer.train()
# Out:
# Overwriting train_grpo.py

# %%
import torch
torch.cuda.device_count()
# Out:
# 1

# %%
# !accelerate launch --config_file config.yaml train_grpo_v2.py
# Out:
# [2025-02-10 01:45:52,187] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 2025-02-10 01:45:53.954792: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-10 01:45:53.970690: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-10 01:45:53.975679: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-10 01:45:53.987492: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# W0210 01:45:55.923000 117327 site-packages/torch/distributed/run.py:793]
# W0210 01:45:55.923000 117327 site-packages/torch/distributed/run.py:793] *****************************************
# W0210 01:45:55.923000 117327 site-packages/torch/distributed/run.py:793] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0210 01:45:55.923000 117327 site-packages/torch/distributed/run.py:793] *****************************************
# 2025-02-10 01:46:00.343368: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-10 01:46:00.359409: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-10 01:46:00.364514: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-10 01:46:00.376256: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-10 01:46:00.442772: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-10 01:46:00.458753: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-10 01:46:00.463793: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-10 01:46:00.475302: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-10 01:46:00.559855: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-10 01:46:00.574904: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-10 01:46:00.574912: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-10 01:46:00.575937: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-10 01:46:00.581065: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-10 01:46:00.591205: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-10 01:46:00.591207: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-10 01:46:00.592902: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-10 01:46:00.593851: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-10 01:46:00.594105: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-10 01:46:00.596275: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-10 01:46:00.596298: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-10 01:46:00.608647: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-10 01:46:00.608659: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-10 01:46:00.609836: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-10 01:46:00.610409: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-10 01:46:00.614843: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-10 01:46:00.615575: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-10 01:46:00.626963: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-10 01:46:00.627489: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-10 01:46:00.691038: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-10 01:46:00.707022: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-10 01:46:00.712055: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-10 01:46:00.723914: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [2025-02-10 01:46:02,532] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-02-10 01:46:02,894] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-02-10 01:46:03,522] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-02-10 01:46:03,536] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-02-10 01:46:03,594] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-02-10 01:46:03,647] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-02-10 01:46:03,875] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-02-10 01:46:04,010] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# INFO 02-10 01:46:05 __init__.py:190] Automatically detected platform cuda.
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# INFO 02-10 01:46:06 __init__.py:190] Automatically detected platform cuda.
# INFO 02-10 01:46:06 __init__.py:190] Automatically detected platform cuda.
# INFO 02-10 01:46:06 __init__.py:190] Automatically detected platform cuda.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# INFO 02-10 01:46:06 __init__.py:190] Automatically detected platform cuda.
# INFO 02-10 01:46:06 __init__.py:190] Automatically detected platform cuda.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 02-10 01:46:07 __init__.py:190] Automatically detected platform cuda.
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# INFO 02-10 01:46:07 __init__.py:190] Automatically detected platform cuda.
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.2.4: Fast Llama patching. Transformers: 4.48.2.
#    \\   /|    GPU: NVIDIA A10G. Max memory: 21.975 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.6. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.2.4: Fast Llama patching. Transformers: 4.48.2.
#    \\   /|    GPU: NVIDIA A10G. Max memory: 21.975 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.6. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# ==((====))==  Unsloth 2025.2.4: Fast Llama patching. Transformers: 4.48.2.
#    \\   /|    GPU: NVIDIA A10G. Max memory: 21.975 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.6. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# ==((====))==  Unsloth 2025.2.4: Fast Llama patching. Transformers: 4.48.2.
#    \\   /|    GPU: NVIDIA A10G. Max memory: 21.975 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.6. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: vLLM loading unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit with actual GPU utilization = 69.2%
# Unsloth: Your GPU has CUDA compute capability 8.6 with VRAM = 21.98 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 4096. Num Sequences = 256.
# Unsloth: vLLM's KV Cache can use up to 14.13 GB. Also swap space = 6 GB.
# ==((====))==  Unsloth 2025.2.4: Fast Llama patching. Transformers: 4.48.2.
#    \\   /|    GPU: NVIDIA A10G. Max memory: 21.975 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.6. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# ==((====))==  Unsloth 2025.2.4: Fast Llama patching. Transformers: 4.48.2.
#    \\   /|    GPU: NVIDIA A10G. Max memory: 21.975 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.6. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# ==((====))==  Unsloth 2025.2.4: Fast Llama patching. Transformers: 4.48.2.
#    \\   /|    GPU: NVIDIA A10G. Max memory: 21.975 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.6. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# ==((====))==  Unsloth 2025.2.4: Fast Llama patching. Transformers: 4.48.2.
#    \\   /|    GPU: NVIDIA A10G. Max memory: 21.975 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.6. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: vLLM loading unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit with actual GPU utilization = 68.21%
# Unsloth: Your GPU has CUDA compute capability 8.6 with VRAM = 21.98 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 4096. Num Sequences = 256.
# Unsloth: vLLM's KV Cache can use up to 13.91 GB. Also swap space = 6 GB.
# Unsloth: vLLM loading unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit with actual GPU utilization = 67.63%
# Unsloth: Your GPU has CUDA compute capability 8.6 with VRAM = 21.98 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 4096. Num Sequences = 256.
# Unsloth: vLLM's KV Cache can use up to 13.78 GB. Also swap space = 6 GB.
# Unsloth: vLLM loading unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit with actual GPU utilization = 66.05%
# Unsloth: Your GPU has CUDA compute capability 8.6 with VRAM = 21.98 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 4096. Num Sequences = 256.
# Unsloth: vLLM's KV Cache can use up to 13.44 GB. Also swap space = 6 GB.
# Unsloth: vLLM loading unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit with actual GPU utilization = 66.05%
# Unsloth: Your GPU has CUDA compute capability 8.6 with VRAM = 21.98 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 4096. Num Sequences = 256.
# Unsloth: vLLM's KV Cache can use up to 13.44 GB. Also swap space = 6 GB.
# Unsloth: vLLM loading unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit with actual GPU utilization = 65.22%
# Unsloth: Your GPU has CUDA compute capability 8.6 with VRAM = 21.98 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 4096. Num Sequences = 256.
# Unsloth: vLLM's KV Cache can use up to 13.25 GB. Also swap space = 6 GB.
# Unsloth: vLLM loading unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit with actual GPU utilization = 64.47%
# Unsloth: Your GPU has CUDA compute capability 8.6 with VRAM = 21.98 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 4096. Num Sequences = 256.
# Unsloth: vLLM's KV Cache can use up to 13.09 GB. Also swap space = 6 GB.
# Unsloth: vLLM loading unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit with actual GPU utilization = 63.69%
# Unsloth: Your GPU has CUDA compute capability 8.6 with VRAM = 21.98 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 4096. Num Sequences = 256.
# Unsloth: vLLM's KV Cache can use up to 12.92 GB. Also swap space = 6 GB.
# INFO 02-10 01:46:18 config.py:542] This model supports multiple tasks: {'reward', 'embed', 'generate', 'classify', 'score'}. Defaulting to 'generate'.
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'bfloat16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['lm_head', 'multi_modal_projector', 'merger', 'modality_projection', 'model.layers.1.mlp'], 'llm_int8_threshold': 6.0}
# INFO 02-10 01:46:19 llm_engine.py:234] Initializing a V0 LLM engine (v0.7.2) with config: model='unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit', speculative_config=None, tokenizer='unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=4096, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":0,"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":256}, use_cached_outputs=False,
# INFO 02-10 01:46:19 config.py:542] This model supports multiple tasks: {'score', 'reward', 'generate', 'embed', 'classify'}. Defaulting to 'generate'.
# INFO 02-10 01:46:20 config.py:542] This model supports multiple tasks: {'classify', 'score', 'generate', 'reward', 'embed'}. Defaulting to 'generate'.
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'bfloat16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['lm_head', 'multi_modal_projector', 'merger', 'modality_projection', 'model.layers.1.mlp'], 'llm_int8_threshold': 6.0}
# INFO 02-10 01:46:20 llm_engine.py:234] Initializing a V0 LLM engine (v0.7.2) with config: model='unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit', speculative_config=None, tokenizer='unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=4096, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":0,"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":256}, use_cached_outputs=False,
# INFO 02-10 01:46:20 cuda.py:230] Using Flash Attention backend.
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'bfloat16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['lm_head', 'multi_modal_projector', 'merger', 'modality_projection', 'model.layers.1.mlp'], 'llm_int8_threshold': 6.0}
# INFO 02-10 01:46:20 llm_engine.py:234] Initializing a V0 LLM engine (v0.7.2) with config: model='unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit', speculative_config=None, tokenizer='unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=4096, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":0,"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":256}, use_cached_outputs=False,
# INFO 02-10 01:46:20 config.py:542] This model supports multiple tasks: {'reward', 'classify', 'score', 'embed', 'generate'}. Defaulting to 'generate'.
# INFO 02-10 01:46:20 config.py:542] This model supports multiple tasks: {'generate', 'score', 'reward', 'classify', 'embed'}. Defaulting to 'generate'.
# INFO 02-10 01:46:20 config.py:542] This model supports multiple tasks: {'score', 'generate', 'classify', 'embed', 'reward'}. Defaulting to 'generate'.
# INFO 02-10 01:46:20 cuda.py:230] Using Flash Attention backend.
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'bfloat16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['lm_head', 'multi_modal_projector', 'merger', 'modality_projection', 'model.layers.1.mlp'], 'llm_int8_threshold': 6.0}
# INFO 02-10 01:46:21 llm_engine.py:234] Initializing a V0 LLM engine (v0.7.2) with config: model='unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit', speculative_config=None, tokenizer='unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=4096, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":0,"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":256}, use_cached_outputs=False,
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'bfloat16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['lm_head', 'multi_modal_projector', 'merger', 'modality_projection', 'model.layers.1.mlp'], 'llm_int8_threshold': 6.0}
# INFO 02-10 01:46:21 llm_engine.py:234] Initializing a V0 LLM engine (v0.7.2) with config: model='unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit', speculative_config=None, tokenizer='unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=4096, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":0,"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":256}, use_cached_outputs=False,
# INFO 02-10 01:46:21 cuda.py:230] Using Flash Attention backend.
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'bfloat16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['lm_head', 'multi_modal_projector', 'merger', 'modality_projection', 'model.layers.1.mlp'], 'llm_int8_threshold': 6.0}
# INFO 02-10 01:46:21 llm_engine.py:234] Initializing a V0 LLM engine (v0.7.2) with config: model='unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit', speculative_config=None, tokenizer='unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=4096, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":0,"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":256}, use_cached_outputs=False,
# INFO 02-10 01:46:21 config.py:542] This model supports multiple tasks: {'generate', 'reward', 'score', 'embed', 'classify'}. Defaulting to 'generate'.
# INFO 02-10 01:46:22 cuda.py:230] Using Flash Attention backend.
# INFO 02-10 01:46:22 cuda.py:230] Using Flash Attention backend.
# INFO 02-10 01:46:22 config.py:542] This model supports multiple tasks: {'reward', 'score', 'classify', 'generate', 'embed'}. Defaulting to 'generate'.
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'bfloat16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['lm_head', 'multi_modal_projector', 'merger', 'modality_projection', 'model.layers.1.mlp'], 'llm_int8_threshold': 6.0}
# INFO 02-10 01:46:22 llm_engine.py:234] Initializing a V0 LLM engine (v0.7.2) with config: model='unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit', speculative_config=None, tokenizer='unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=4096, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":0,"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":256}, use_cached_outputs=False,
# INFO 02-10 01:46:22 cuda.py:230] Using Flash Attention backend.
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'bfloat16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['lm_head', 'multi_modal_projector', 'merger', 'modality_projection', 'model.layers.1.mlp'], 'llm_int8_threshold': 6.0}
# INFO 02-10 01:46:22 llm_engine.py:234] Initializing a V0 LLM engine (v0.7.2) with config: model='unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit', speculative_config=None, tokenizer='unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=4096, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=unsloth/llama-3.2-1b-instruct-unsloth-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":0,"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":256}, use_cached_outputs=False,
# INFO 02-10 01:46:22 cuda.py:230] Using Flash Attention backend.
# INFO 02-10 01:46:23 cuda.py:230] Using Flash Attention backend.

# %%
import torch

torch._dynamo.list_backends()
# Out:
# ['cudagraphs', 'inductor', 'onnxrt', 'openxla', 'openxla_eval', 'tvm']
